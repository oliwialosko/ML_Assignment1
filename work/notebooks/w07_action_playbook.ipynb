# %% [markdown]
# <a href="https://colab.research.google.com/github/oliwialosko/ML_Assignment1/blob/main/work/notebooks/w07_action_playbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-10 — Content Action Playbook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/oliwialosko/ML_Assignment1/blob/main/work/notebooks/w07_action_playbook.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Ranked actions + reason codes
#
# *The queue: what to do first, and why, in words a human trusts.*

# %% [markdown]
# The playbook prioritizes pages with a high risk score (>50% probability of >30% traffic drop) combined with high historical click value. The actions are categorized by combining the XGBoost risk probability with strict SEO heuristics:
#
# - Refresh Mature Content: Targets aging content (>6 months) that is decaying. Action: Update outdated facts, add new examples, and refresh the publication date.
#
# - Urgent Snippet Rewrite: Targets pages ranking well (top 20) but suffering from poor click-through rates (< 1.0%). Action: Rewrite the title and meta description to better match search intent.
#
# - Boost High-Volume Edge: Targets pages with substantial past impressions (>1000) that are at risk of slipping. Action: Expand the content depth to secure the ranking.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Intended use and limits
#
# *Who uses this, for what — and where it stops being valid.*

# %% [markdown]
# - Intended Use: This model serves as a monthly decision-support tool for editorial teams. It highlights which pages require immediate intervention to prevent organic traffic decay, effectively sorting the content refresh queue by empirical risk rather than guesswork.
#
# - Limits: The model is architected around a strict 15-day rolling window, making it a short-term volatility radar rather than a predictor of long-term organic trends. Consequently, it is blind to macro-seasonality (e.g., natural post-holiday traffic drops) and assumes search engine algorithms remain stable. It should not be used for overall site health forecasting.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Human review + the no-go list
#
# *What a person must check before acting. What should never be automated.*

# %% [markdown]
# - Human Review Required: Before modifying a flagged page, an editor must verify if the drop is caused by natural seasonality (e.g., a "Black Friday" page dropping in January) or a recent out-of-scope event (e.g., a site migration or temporary server downtime).
#
# - The No-Go List: Never automate the actual rewriting and publishing of content purely based on these flags. Machine-generated content updates or automated snippet changes without editorial QA can severely harm domain authority and brand safety.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Monitoring / retrain triggers
#
# *What would tell you the recommendations went stale?*

# %% [markdown]
# To ensure the model does not go stale, performance must be monitored using the holdout precision metric (Precision@K).
# Retraining should be triggered under the following conditions:
#
# - Performance Degradation: If the model's out-of-distribution Precision@50 drops below the expert heuristic baseline.
#
# - Environment Shift: Following a confirmed, major Google Core Algorithm Update, which fundamentally alters how behavioral signals (like CTR or scroll depth) are weighted in search engine results.
#
# - Data Drift: Significant changes in the underlying portfolio structure, such as onboarding a massive new client in a completely unseen niche (like shifting from informational blogs to heavy e-commerce).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Exports for the paper
#
# *Write the queue (and any figures you want to reuse) to work/outputs/ — your paper builds on these files.*

# %% [markdown]
# The actionable queue has been successfully generated during the validation phase and you can see it under https://github.com/oliwialosko/ML_Assignment1/blob/main/work/notebooks/capstone.ipynb (point 6)

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
