# %% [markdown]
# <a href="https://colab.research.google.com/github/oliwialosko/ML_Assignment1/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/oliwialosko/ML_Assignment1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I am choosing Lane 2: Refresh / Content Opportunity Scoring. I chose this direction because it represents a classic but real-world machine learning problem on tabular data: Building a ranking of pages that require a refresh to generate reason codes for human reviewers.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# - Decision: Which of the existing website pages should be reviewed first for a content refresh or expansion.
#
# - Action: An expert (human) analyzes a recommended page, and then decides whether to improve title/meta tags, better match user intent, optimize on-page elements, or monitor it further.
#
# - Cost of a wrong call: A false positive recommendation leads to wasting the expert's valuable time analyzing and editing a page that has no real chance of increased engagement. Conversely, ignoring a good opportunity (False Negative) means missing out on potential traffic. Optimization will focus on a top-K metric (like Precision@50), which will be much more useful than overall accuracy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    # find the repo root from wherever this kernel started
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter
# Starter data found. You're ready.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
total_pages = len(df)
declining_pages = len(df[df['trend_direction'] == 'down'])

# Filter for pages that have enough traffic volume to be worth reviewing
high_vol_declining = len(df[(df['trend_direction'] == 'down') & (df['impressions_90d'] >= 500)])

print(f"Total content items in starter set: {total_pages:,}")
print(f"Pages showing a negative trend: {declining_pages:,} ({declining_pages/total_pages:.1%})")
print(f"High-volume declining pages (>= 500 impressions): {high_vol_declining:,}")
print(f"This leaves a highly concentrated queue of {high_vol_declining:,} pages where a human reviewer's time is best spent.")
# Out:
# Total content items in starter set: 30,000
# Pages showing a negative trend: 16,262 (54.2%)
# High-volume declining pages (>= 500 impressions): 9,961
# This leaves a highly concentrated queue of 9,961 pages where a human reviewer's time is best spent.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My work will provide a decision-support tool that only prioritizes improvement opportunities based on observed and directional changes in engagement metrics. The system will evaluate the risk of decline or the opportunity for recovery, but it will not guarantee that refreshing the content will always restore traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
